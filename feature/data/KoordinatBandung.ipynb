# %%
import pandas as pd

koordinat_BDG = pd.read_csv('../../datasets/Koordinat_kecamatan_kota_bandung.csv')

display(koordinat_BDG)

# %store koordinat_BDG
# Out:
#            kecamatan  Lintang Selatan   Bujur Timur Ketinggian (dpl);
# 0      Bandung Kulon        -6.925200      107.5745              709;
# 1    Babakan Ciparay        -6.939550   107.576887;               NaN
# 2    Bojongloa Kaler        -6.930256   107.590506;               NaN
# 3    Bojongloa Kidul        -6.950118   107.597414;               NaN
# 4       Astana Anyar        -6.931900      107.5998              695;
# 5              Regol        -6.946070      107.6118              686;
# 6           Lengkong        -6.928100      107.6241              696;
# 7      Bandung Kidul        -6.959000      107.6365              670;
# 8           Buahbatu        -6.950300   107.653338;               NaN
# 9          Rancasari        -6.948000      107.6749              670;
# 10          Gedebage        -6.955080   107.699592;               NaN
# 11            Cibiru        -6.929100        107.72              706;
# ...
