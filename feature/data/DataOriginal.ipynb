# %%
# Data Asli

import pandas as pd

data_path = '../../datasets/Dataset_dummy_v2.csv'
data_sampah = pd.read_csv(data_path)
data_sampah['tanggal'] = pd.to_datetime(data_sampah['tanggal'])

display(data_sampah)

# %store data_sampah
# Out:
#           id    tanggal         kecamatan  jumlah_sampah satuan
# 0          1 2016-01-01             Regol            2.2    TON
# 1          2 2016-01-01      Kiaracondong            2.4    TON
# 2          3 2016-01-01  Cibeunying Kaler            1.4    TON
# 3          4 2016-01-01          Sukajadi            1.8    TON
# 4          5 2016-01-01      Astana Anyar            2.5    TON
# ...      ...        ...               ...            ...    ...
# 73943  73944 2023-11-30       Ujungberung            6.1    TON
# 73944  73945 2023-11-30   Bojongloa Kaler            5.3    TON
# 73945  73946 2023-11-30   Babakan Ciparay            5.7    TON
# 73946  73947 2023-11-30     Bandung Wetan            5.1    TON
# 73947  73948 2023-11-30     Bandung Kidul            6.1    TON
#
# [73948 rows x 5 columns]
# Stored 'data_sampah' (DataFrame)

# %%
import pandas as pd

# Gunakan path relatif dari lokasi notebook atau script Anda
data_path = '../../datasets/Dataset_dummy_v2.csv'

# Membaca data dari file CSV
data_sampah = pd.read_csv(data_path)
#groupping kecamatan
grouping_kecamtan = data_sampah.groupby('kecamatan')

andir = grouping_kecamtan.get_group('Andir')
astana_anyar = grouping_kecamtan.get_group('Astana Anyar')
antapani = grouping_kecamtan.get_group('Antapani')
arcamanik = grouping_kecamtan.get_group('Arcamanik')
babakan_ciparay = grouping_kecamtan.get_group('Babakan Ciparay')
bandung_kidul = grouping_kecamtan.get_group('Bandung Kidul')
bandung_kulon = grouping_kecamtan.get_group('Bandung Kulon')
bandung_wetan = grouping_kecamtan.get_group('Bandung Wetan')
batununggal = grouping_kecamtan.get_group('Batununggal')
bojongloa_kaler = grouping_kecamtan.get_group('Bojongloa Kaler')
bojongloa_kidul = grouping_kecamtan.get_group('Bojongloa Kidul')
buahbatu = grouping_kecamtan.get_group('Buahbatu')
cibeunying_kaler = grouping_kecamtan.get_group('Cibeunying Kaler')
cibeunying_kidul = grouping_kecamtan.get_group('Cibeunying Kidul')
cibiru = grouping_kecamtan.get_group('Cibiru')
cicendo = grouping_kecamtan.get_group('Cicendo')
cidadap = grouping_kecamtan.get_group('Cidadap')
cinambo = grouping_kecamtan.get_group('Cinambo')
coblong = grouping_kecamtan.get_group('Coblong')
gedebage = grouping_kecamtan.get_group('Gedebage')
kiaracondong = grouping_kecamtan.get_group('Kiaracondong')
lengkong = grouping_kecamtan.get_group('Lengkong')
mandalajati = grouping_kecamtan.get_group('Mandalajati')
panyileukan = grouping_kecamtan.get_group('Panyileukan')
rancasari = grouping_kecamtan.get_group('Rancasari')
regol = grouping_kecamtan.get_group('Regol')
sukajadi = grouping_kecamtan.get_group('Sukajadi')
sukasari = grouping_kecamtan.get_group('Sukasari')
sumur_bandung = grouping_kecamtan.get_group('Sumur Bandung')
ujung_berung = grouping_kecamtan.get_group('Ujungberung')
# Out:
#           id     tanggal kecamatan  jumlah_sampah satuan
# 0          1    1/1/2016     Regol            2.2    TON
# 13        14    1/2/2016     Regol            1.2    TON
# 100      101    1/5/2016     Regol            1.5    TON
# 107      108    1/6/2016     Regol            2.3    TON
# 152      153    1/7/2016     Regol            1.3    TON
# ...      ...         ...       ...            ...    ...
# 73774  73775  11/23/2023     Regol            5.7    TON
# 73847  73848  11/26/2023     Regol            6.2    TON
# 73888  73889  11/28/2023     Regol            5.8    TON
# 73907  73908  11/29/2023     Regol            6.3    TON
# 73929  73930  11/30/2023     Regol            5.9    TON
#
# [2392 rows x 5 columns]

# %%
var_kecamatan = ["Andir","Astana Anyar","Antapani","Arcamanik","Babakan Ciparay","Bandung Kidul","Bandung Kulon","Bandung Wetan","Batununggal",
    "Bojongloa Kaler","Bojongloa Kidul","Buahbatu","Cibeunying Kaler","Cibeunying Kidul","Cibiru","Cicendo","Cidadap","Cinambo","Coblong","Gedebage",
    "Kiaracondong","Lengkong","Mandalajati","Panyileukan","Rancasari","Regol","Sukajadi","Sukasari","Sumur Bandung","Ujungberung"
]

list_grup_kecamatan = [andir,astana_anyar, antapani,arcamanik,babakan_ciparay,bandung_kidul,bandung_kulon,bandung_wetan,batununggal,bojongloa_kaler,bojongloa_kidul,buahbatu,
                       cibeunying_kaler,cibeunying_kidul,cibiru,cicendo,cidadap,cinambo,coblong,gedebage,kiaracondong,lengkong,mandalajati,panyileukan,rancasari,regol,sukajadi,
                       sukasari,sumur_bandung,ujung_berung
                       ]
