# %%
import matplotlib.pyplot as plt

# %store -r top_5_kecamatan_signifikan

# Membuat plot batang untuk setiap kecamatan
fig, ax = plt.subplots(figsize=(12, 6))

# Warna untuk mewakili kecamatan yang berbeda
colors = ['red', 'orange', 'purple', 'blue', 'green']

ax.bar(top_5_kecamatan_signifikan['kecamatan'], top_5_kecamatan_signifikan['peningkatan_sampah'], color=colors)

# Menambahkan label dan legenda
ax.set_title('5 Kecamatan dengan Peningkatan Sampah Paling Signifikan pertahunnya')
ax.set_xlabel('Kecamatan')
ax.set_ylabel('Peningkatan Sampah (TON)')

# Menampilkan plot
plt.show()
