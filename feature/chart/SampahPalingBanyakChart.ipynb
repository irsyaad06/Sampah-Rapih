# %%
import matplotlib.pyplot as plt

# %store -r top_5_data_banyak

fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(top_5_data_banyak['jumlah_sampah'], labels=top_5_data_banyak.index, autopct='%1.1f%%', startangle=90)

plt.style.use('_mpl-gallery')
plt.title('Top 5 Kecamatan dengan Kenaikan Sampah Terbanyak per Tahunnya')
plt.show()
