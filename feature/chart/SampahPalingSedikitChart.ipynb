# %%
import matplotlib.pyplot as plt

# %store -r top_5_data_sedikit

fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(top_5_data_sedikit['jumlah_sampah'], labels=top_5_data_sedikit.index, autopct='%1.1f%%', startangle=90)

plt.style.use('_mpl-gallery')
plt.title('Jumlah Sampah 5 Kecamatan Tersedikit')
plt.show()

# display(top_5_data_sedikit)
